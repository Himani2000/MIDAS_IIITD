# %% [markdown]
# Importing the header file
# if import error comes then --pip3 install filename(if on ubuntu else pip will work)

# %%
import tweepy
import json
import pandas as pd
import numpy as np

# %% [markdown]
# Make a twitter account if not go to the twitter developers and make a app by filling some details and get the tokens and
# keys in the keys and tokens tab above

# %% [markdown]
# Also make sure  you do not share such details so  i have marked it xx

# %%
ACCESS_TOKEN ="xxxxxxxxx"
ACCESS_TOKEN_SECRET ="xxxxxxxx"
CONSUMER_KEY = "xxxxxxxxxxxx" 
CONSUMER_SECRET = "xxxxxxxxxx"

# %% [markdown]
# #here the function himani tweets ask for the username and the number of tweets as  the function
# #the  username can be  any twitter account for the question we have taken the midasIIITD

# %%
def himani_tweets(username,number_of_tweets=250): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET) 
  
        # Calling  twiiter api 
        api = tweepy.API(auth) 
   
        # getting the tweets through calling the api by giving the username and the count of the tweets 
        tweets = api.user_timeline(screen_name=username,count=number_of_tweets) 
  
        # making a json file and appending the tweets 
        with open(username+".jsonl",'w') as f:
            for tweet in tweets:
                json.dump(tweet._json, f)
                f.write('\n')
        # converting the json file to the pandas dataframe 
        df=pd.read_json(username+".jsonl",lines=True)
        # returning the dataframe 
        return df

# %%
#asking the user for the input of the number of tweets we can also do this for username too
num=int(input("Enter the number of tweets"))
username="midasIIITD"
# Out:
# Enter the number of tweets200

# %%
#calling the function and saving the dataframe 
df_new=himani_tweets("midasIIITD",num)

# %%
# for  showing only first  5  records 
df_new.head()
# Out:
#    contributors  coordinates          created_at  \
# 0           NaN          NaN 2019-04-10 09:01:29
# 1           NaN          NaN 2019-04-10 04:51:26
# 2           NaN          NaN 2019-04-09 16:45:07
# 3           NaN          NaN 2019-04-09 05:04:27
# 4           NaN          NaN 2019-04-09 05:04:11
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'urls': [{'expanded_url': 'htt...               NaN
# 1  {'symbols': [], 'urls': [], 'hashtags': [], 'u...               NaN
# 2  {'symbols': [], 'urls': [], 'hashtags': [], 'u...               NaN
# 3  {'symbols': [], 'urls': [{'expanded_url': 'htt...               NaN
# 4  {'symbols': [], 'urls': [], 'hashtags': [], 'u...               NaN
#
#    favorite_count  favorited  geo                   id               id_str  \
# 0               0      False  NaN  1115902611599822852  1115902611599822848
# 1               0      False  NaN  1115839682607239173  1115839682607239168
# ...

# %%
df_new.describe() # for getting the description of the dataframe
# Out:
#        contributors  coordinates  favorite_count  geo            id  \
# count           0.0          0.0      200.000000  0.0  2.000000e+02
# mean            NaN          NaN        2.615000  NaN  1.096765e+18
# std             NaN          NaN        4.276472  NaN  1.218670e+16
# min             NaN          NaN        0.000000  NaN  1.074710e+18
# 25%             NaN          NaN        0.000000  NaN  1.087382e+18
# 50%             NaN          NaN        0.000000  NaN  1.096570e+18
# 75%             NaN          NaN        4.000000  NaN  1.107651e+18
# max             NaN          NaN       24.000000  NaN  1.115903e+18
#
#              id_str  in_reply_to_status_id  in_reply_to_status_id_str  \
# count  2.000000e+02           3.600000e+01               3.600000e+01
# mean   1.096765e+18           1.096568e+18               1.096568e+18
# std    1.218670e+16           1.208872e+16               1.208872e+16
# min    1.074710e+18           1.065095e+18               1.065095e+18
# ...

# %%
df_new.columns  # for showing the total columns of the dataframe
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'extended_entities', 'favorite_count', 'favorited', 'geo', 'id',
#        'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'quoted_status', 'quoted_status_id',
#        'quoted_status_id_str', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'text', 'truncated', 'user'],
#       dtype='object')

# %% [raw]
# For  only showing the necessory information as mentioned in the qquestion

# %%
df_new2=pd.DataFrame(df,columns=["text","favorite_count","created_at","retweet_count","media_url_https"])

# %%
df_new2.head()
# Out:
#                                                 text  favorite_count  \
# 0  Clarification: Our earlier post which indicate...               0
# 1  RT @IIITDelhi: Applications open for MTech (CB...               0
# 2  RT @IIITDelhi: We are delighted to share that ...               0
# 3  RT @Harvard: Professor Jelani Nelson founded A...               0
# 4  RT @emnlp2019: For anyone interested in submit...               0
#
#            created_at  retweet_count  media_url_https
# 0 2019-04-10 09:01:29              0              NaN
# 1 2019-04-10 04:51:26              1              NaN
# 2 2019-04-09 16:45:07             14              NaN
# 3 2019-04-09 05:04:27             36              NaN
# 4 2019-04-09 05:04:11             17              NaN

# %%
df_new2['media_url_https'].unique()
# Out:
# array([nan])
